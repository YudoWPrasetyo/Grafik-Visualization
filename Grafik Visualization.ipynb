# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df_iris = sns.load_dataset('iris')
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df_tips = sns.load_dataset('tips')
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Barplot

# %%
sns.barplot(x='sex',y='total_bill', data=df_tips, hue='sex')
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.barplot(df_tips['sex'],df_tips['total_bill'])
plt.title('barplot using seaborn')
plt. show()

# %%
plt.figure(figsize=(8,7))
sns.barplot(df_tips['day'],df_tips['total_bill'])
plt.title('barplot using seaborn')
plt. show()

# %%
plt.figure(figsize=(8,7))
sns.barplot(y=df_tips['day'], x=df_tips['total_bill'])
plt.title('barplot using seaborn')
plt. show()

# %%
# Countplot

# %%
sns.countplot(df_tips['sex'])
plt.show()

# %%
df_tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
pd.crosstab(df_tips['sex'],columns='Jumlah')
# Out:
# col_0   Jumlah
# sex
# Male       157
# Female      87

# %%
pd.crosstab(index=df_tips['day'], columns='Rata-rata', values=df_tips['total_bill'], aggfunc='mean')
# Out:
# col_0  Rata-rata
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.figure(figsize=(8,7))
sns.barplot(df_tips['day'],df_tips['total_bill'])
plt.title('barplot using seaborn')
plt. show()

# %%
df_tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
pd.crosstab(df_tips['day'], columns='Count')
# Out:
# col_0  Count
# day
# Thur      62
# Fri       19
# Sat       87
# Sun       76

# %%
plt.figure(figsize=(8,7))
sns.countplot(df_tips['day'])
plt.title('tabel jumlah transaksi per hari')
plt.show()

# %%
# Boxplot

# %%
sns.boxplot(df_tips['total_bill'])
plt.show()

# %%
sns.boxplot(x=df_tips['day'], y=df_tips['total_bill'])
plt.show()

# %%
sns.boxplot(x=df_tips['day'], y=df_tips['total_bill'], palette='terrain')
plt.show()

# %%
sns.boxplot(data=df_tips, palette='terrain')
plt.show()

# %%
sns.boxplot(data=df_tips['total_bill'])
plt.show()

# %%
df_tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
plt.figure(figsize=(8,7))
sns.boxplot(y='day', x='total_bill', palette='hot', data=df_tips)
plt.savefig('box.png')
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.boxplot(x='day', y='total_bill', palette='hot', data=df_tips, hue='sex')
plt.show()

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# violin plot => untuk distribusi data mirip boxplot

# %%
plt.figure(figsize=(8,7))
sns.violinplot(x='day', y='total_bill', palette='Accent', data=df_tips)
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.violinplot(x='day', y='total_bill', palette='Accent', data=df_tips, hue='sex')
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.violinplot(x='day', y='total_bill', palette='Accent', data=df_tips, hue='smoker')
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.violinplot(x='day', y='total_bill', palette='Accent', data=df_tips, hue='sex', split=True)
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.violinplot(x='day', y='total_bill', palette='Accent', data=df_tips, hue='smoker', split=True)
plt.show()

# %%
# Striplot

# %%
# sns.pairplot(df_tips);

# %%
plt.figure(figsize=(8,7))
sns.stripplot(x='day', y='total_bill', palette='cool', data=df_tips)
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.stripplot(x='day', y='total_bill', palette='cool', data=df_tips, jitter=False)
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.stripplot(x='day', y='total_bill', palette='cool', data=df_tips, hue='sex')
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.stripplot(x='day', y='total_bill', palette='cool', data=df_tips, hue='sex', dodge=True)
plt.show()

# %%
# Swarmplot ==> Fungsi mirip dengan stripplot, hanya data yang nilainya saa tidak akan ditumpuk di titik yang sama

# %%
plt.figure(figsize=(8,7))
sns.swarmplot(x='day', y = 'total_bill', palette = 'Set1', data = df_tips)
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.swarmplot(x='day', y = 'total_bill', palette = 'Set1', data = df_tips, hue= 'sex')
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.swarmplot(x='day', y = 'total_bill', palette = 'Set1', data = df_tips, hue= 'sex', dodge = True)
plt.show()

# %%
sns.barplot(x=df_tips['day'], y=df_tips['total_bill']) # Nilai Rata Rata
plt.show()

# %%
#Plot Kolom Kategorikal
sns.catplot(x='day', y = 'total_bill', data = df_tips, kind='bar')
plt.show()

# %%
sns.catplot(x='day', y = 'total_bill', data = df_tips, kind='swarm')
plt.show()

# %%
sns.catplot(x='day', y = 'total_bill', data = df_tips, kind='strip')
plt.show()

# %%
sns.catplot(x='day', y = 'total_bill', data = df_tips, kind='violin')
plt.show()

# %%
df_tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
## HEATMAP

# %%
sns.heatmap(df_tips.corr())
plt.show()

# %%
sns.heatmap(df_tips.corr(), annot=True) # fungis annot=True untuk menampilkan nilai korelasi
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.heatmap(df_tips.corr(), annot=True)
plt.show()

# %% [markdown]
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
plt.figure(figsize=(8,7))
sns.heatmap(df_tips.corr(),annot=True, cmap='gist_rainbow')
plt.show()

# %%
plt.figure(figsize=(8,7)) 
sns.heatmap(df_tips.corr(),annot=True, cmap='gist_rainbow', linewidth=2, linecolor='Black') # Memisahkan garis hitam
plt.show()

# %%
df_flights = sns.load_dataset('flights')
df_flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
pd.crosstab(index=df_flights['month'], columns=df_flights['year'],
           values=df_flights['passengers'], aggfunc='sum')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
df_pas = pd.crosstab(index=df_flights['month'], columns=df_flights['year'],
           values=df_flights['passengers'], aggfunc='sum')

# %%
plt.figure(figsize=(9,8))
sns.heatmap(df_pas)
plt.show()

# %%
plt.figure(figsize=(9,8))
sns.heatmap(df_pas, cmap ='cool', linewidth=1)
plt.show()

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Histogram
# - Untuk melihat distribusi data
# - Untuk kolom numerik - Continous
# - Univariate Kolom Numerik
# - KDE ==> Kernel Density Estimation

# %%
sns.distplot(df_tips['total_bill']) # KDE distplot
plt.show()

# %%
sns.distplot(df_tips['total_bill'], kde= False) # kde = False untuk mengeluarkan histogramnya saja tanpa ada garis
plt.show()

# %%
sns.distplot(df_tips['total_bill'], hist=False) # hist=Falase untuk menampilkan garisnya saja
plt.show()

# %%
sns.distplot(df_tips['total_bill'], kde=False, bins=10)
plt.show()

# %%
### ANALISA MULTIVARIATE

# %%
sns.jointplot(x='total_bill', y = 'tip', data=df_tips) ## dua kolom yang digunakan adalah kolom Numerik-Continous
plt.show()

# %%
sns.jointplot(x='total_bill', y = 'tip', data=df_tips, kind='hex')
plt.show()

# %%
sns.jointplot(x='total_bill', y = 'tip', data=df_tips, kind='reg', color='red')# kind='reg' untuk menampilkan garis kolerasi
plt.show()

# %%
sns.pairplot(df_tips) # MEnampilkan keseluruhan grafik
plt.show()

# %%
sns.pairplot(df_tips, palette ='Set1', hue ='sex')
plt.show()

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.PairGrid(df_iris)
plt.show()

# %%
P = sns.PairGrid(df_iris)
P.map(plt.scatter) # Menampilkan grafik skatter pada tempat tabel yg tersedia
plt.show()

# %%
P = sns.PairGrid(df_iris)
P.map(plt.hist) # Tidak bisa tampil karena bins lebih dari satu:
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17448/1245906624.py in <module>
#       1 P = sns.PairGrid(df_iris)
# ----> 2 P.map(plt.hist) # Menampilkan grafik histogram pada tempat tabel yg tersedia
#       3 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, **kwargs)
#    1339         row_indices, col_indices = np.indices(self.axes.shape)
#    1340         indices = zip(row_indices.flat, col_indices.flat)
# -> 1341         self._map_bivariate(func, indices, **kwargs)
#    1342
#    1343         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in _map_bivariate(self, func, indices, **kwargs)
#    1537             if ax is None:  # i.e. we are in corner mode
#    1538                 continue
# -> 1539             self._plot_bivariate(x_var, y_var, ax, func, **kws)
# ...

# %%
P = sns.PairGrid(df_iris)
P.map_diag(plt.hist)
P.map_upper(plt.scatter)
P.map_lower(sns.kdeplot)
plt.show()

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_tips['smoker'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
df_tips['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
# MENGGABUNGKAN KATEGORIKAL DENGAN KATEGORIKAL NAMANYA FacetGrid

# %%
sns.FacetGrid(df_tips, row='smoker', col ='time') # Isi dari row dan col harus Kategorikal
plt.show()

# %%
F = sns.FacetGrid(df_tips, row='smoker', col ='time') # Isi dari row dan col harus Kategorikal
F.map(sns.distplot, 'total_bill')
plt.show()

# %%
df_tips[(df_tips['smoker'] == 'Yes') & (df_tips['time'] =='Lunch')][['total_bill']]
# Out:
#      total_bill
# 80        19.44
# 83        32.68
# 138       16.00
# 191       19.81
# 192       28.44
# 193       15.48
# 194       16.58
# 196       10.34
# 197       43.11
# 198       13.00
# 199       13.51
# 200       18.71
# 201       12.74
# 202       13.00
# 203       16.40
# 204       20.53
# 205       16.47
# 220       12.16
# 221       13.42
# 222        8.58
# 224       13.42
# 225       16.27
# 226       10.09

# %%
F = sns.FacetGrid(df_tips, row='smoker', col ='time') # Isi dari row dan col harus Kategorikal
F.map(sns.boxplot, 'total_bill') # boxplot untuk mencari outlier
plt.show()

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
F = sns.FacetGrid(df_tips, row='smoker', col ='time') # Isi dari row dan col harus Kategorikal
F.map(plt.scatter, 'total_bill', 'tip') # ada 4 kolom : smoker, time, total_bill, tip
plt.show()

# %%
F = sns.FacetGrid(df_tips, row='smoker', col ='time', hue='sex') # Isi dari row dan col harus Kategorikal
F.map(plt.scatter, 'total_bill', 'tip').add_legend() # ada 5 kolom : smoker, time, sex, total_bill, tip
plt.show()

# %%
sns.JointGrid(df_tips['total_bill'], df_tips['tip'])
plt.show()

# %%
J = sns.JointGrid(df_tips['total_bill'], df_tips['tip'])
J.plot(sns.regplot, sns.kdeplot)
plt.show()

# %%
sns.lmplot(x='total_bill', y = 'tip', data =df_tips) #lmplot = linear model plot
plt.show()

# %%
sns.lmplot(x='total_bill', y = 'tip', data =df_tips, hue ='smoker', palette='Set1') #lmplot = linear model plot
plt.show()

# %%
sns.lmplot(x='total_bill', y = 'tip', data =df_tips, hue ='smoker', palette='Set1', markers='p') #lmplot = linear model plot
plt.show()

# %%
sns.lmplot(x='total_bill', y = 'tip', data =df_tips, hue ='smoker', palette='Set1', markers='p', size = 5) #lmplot = linear model plot
plt.show()

# %%
sns.lmplot(x='total_bill', y = 'tip', data =df_tips, hue ='smoker', palette='Set1', markers=['p', '>']) #lmplot = linear model plot
plt.show()

# %%
sns.lmplot(x='total_bill', y = 'tip', data =df_tips, 
           hue ='smoker', palette='Set1', markers=['p', '>'],
          col='sex') #lmplot = linear model plot
plt.show()

# %%
sns.lmplot(x='total_bill', y = 'tip', data =df_tips, 
           hue ='smoker', palette='Set1', markers=['p', '>'],
          col='sex', row = 'time') #lmplot = linear model plot
plt.show()

# %%
sns.lmplot(x='total_bill', y = 'tip', data =df_tips, 
           hue ='smoker', palette='Set1', markers=['p', '>'],
          col='day') #lmplot = linear model plot
plt.show()
# col, row, hue = kolom kategorikal

# %%
# relplot = relational plot
sns.relplot(data=df_flights, x = 'passengers', y = 'month', hue ='year', palette='Set1')
plt.show()
